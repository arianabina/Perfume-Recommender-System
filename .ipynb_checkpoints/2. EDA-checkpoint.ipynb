# %% [markdown]
# # Part 2: Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import itertools
import numpy as np

# %%
# Load the data
df = pd.read_csv('clean_perfume_data.csv')

# %% [markdown]
# ### The Perfume Dataset Contains:
# * 2,493 unique brands
# * 33,157 unique perfumes (the name)
# * 31,953 unique note combinations!

# %%
df.describe()
# Out:
#         brand                perfume         notes
# count   33157                  33157         33157
# unique   2493                  33157         31963
# top      Avon  Sweet Tobacco Spirits  floral notes
# freq      611                      1            63

# %% [markdown]
# ### Which brands have released the most perfumes?
#
# * Below, you can see that it's Avon, having released over 600 perfumes! This makes sense considering Avon was founded in 1886.
# * Other prevalent brands include Guerlain, Victoria's Secret, Givenchy, and Christian Dior.

# %%
# Get the top 20 most frequent brands
top_brands = df['brand'].value_counts().head(20)

# Plot the top 20 brands
plt.figure(figsize=(12, 8))
sns.barplot(x=top_brands.values, y=top_brands.index, palette='viridis')
plt.title('Brands That Produce The Most Perfume (Top 20)')
plt.xlabel('Perfume Count')
plt.ylabel('Brand')
plt.show()

# %% [markdown]
# ### What are the least prevalent brands?
#
# * The below brands only released 1 perfume ever. I've personally never heard of any of these names!

# %%
# Get the counts of each unique brand
brand_counts = df['brand'].value_counts()

# Get the least prevalent brands
least_prevalent_brands = brand_counts.tail(20)

# Plot the least prevalent brands
plt.figure(figsize=(12, 8))
sns.barplot(x=least_prevalent_brands.values, y=least_prevalent_brands.index, palette='viridis')
plt.title('Brands That Released Only 1 Perfume (Top 20)')
plt.xlabel('Count')
plt.ylabel('Brand')
plt.show()

# %% [markdown]
# ### What are the Top 10 most prevalent singular notes (ie not mixed with other notes)?
#
# * I'm not surprised to see that rose is the most common note used! However, I was expecting vanilla to be more prevalent!

# %%
# Filter the DataFrame to include only perfumes with single-word notes
single_word_notes = df[df['notes'].str.count(' ') == 0]['notes']

# top 15 Single notes
top_single_word_notes = single_word_notes.value_counts().head(10)

# Plotting
plt.figure(figsize=(12, 8))  
top_single_word_notes.plot(kind='bar', color=plt.cm.viridis(top_single_word_notes.values / max(top_single_word_notes.values)))
plt.title('Prevalent Single Notes')
plt.xlabel('Note')
plt.ylabel('Frequency')
plt.xticks(rotation=60)  
plt.tight_layout()  
plt.show()

# %% [markdown]
# ### What two-note combinations are most common? (Top 10)
#
# * Rose and sandalwood are the two most commonly combined notes! Notice that jasmine and musk are also popular, each appearing three times within different combos!

# %%
from collections import Counter
import numpy as np

# Create a list to store pairs of adjacent words in each note
pairs = []

# Iterate through each note and extract pairs of adjacent words
for note in df['notes']:
    note_list = note.split(', ')
    sorted_note_list = sorted(note_list)  # Sort the list alphabetically
    for i in range(len(sorted_note_list) - 1):
        pairs.append((sorted_note_list[i], sorted_note_list[i + 1]))

# Count the frequency of each pair of adjacent words
pair_counts = Counter(pairs)

# Get the top 15 pairs of adjacent words
top_pairs = pair_counts.most_common(10)

# Extract the pair combinations and their frequencies
pair_combinations = [pair[0][0] + ', ' + pair[0][1] for pair in top_pairs]
pair_frequencies = [pair[1] for pair in top_pairs]

# Plotting
plt.figure(figsize=(12, 8))
plt.bar(pair_combinations, pair_frequencies, color=plt.cm.viridis(np.array(pair_frequencies) / max(pair_frequencies)))
plt.title('Prevalent Two-Note Combinations')
plt.xlabel('Notes')
plt.ylabel('Frequency')
plt.xticks(rotation=60)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What 3-note combinations are most common? (Top 10)
#
# * The most prevalent combination of three notes was: jasmine + musk + sandalwood
# * musk is in 8 out of ten of the combos!
# * sandalwood and jasmine also appear in 6 out of 10 combos!

# %%
# Create a list to store triplets of adjacent words in each note
triplets = []

# Iterate through each note and extract triplets of adjacent words
for note in df['notes']:
    note_list = note.split(', ')
    sorted_note_list = sorted(note_list)  # Sort the list alphabetically
    for triplet in itertools.combinations(sorted_note_list, 3):  
        sorted_triplet = tuple(sorted(triplet))  
        triplets.append(sorted_triplet)

# Count the frequency of each triplet of adjacent words
triplet_counts = Counter(triplets)

# Get the top 15 triplets of adjacent words
top_triplets = triplet_counts.most_common(10) 

# Extract the triplet combinations and their frequencies
triplet_combinations = [', '.join(triplet) for triplet, _ in top_triplets]
triplet_frequencies = [count for _, count in top_triplets]

# Plotting
plt.figure(figsize=(12, 8))  # Adjust figure size if needed
plt.bar(triplet_combinations, triplet_frequencies, color=plt.cm.viridis(np.array(triplet_frequencies) / max(triplet_frequencies)))
plt.title('Prevalent Three-Note Combinations')
plt.xlabel('Note Combination')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.subplots_adjust(bottom=0.3)  # Adjust the bottom margin
plt.tight_layout()
plt.show()

# %% [markdown]
# ### How many notes does each perfume contain in this dataset?
# * The histogram and boxplot below show that most perfumes contain somewhere between 5 to 12 notes.
# * The outliers start occuring at around 20+ notes

# %%
# Count the number of notes for each perfume
note_counts_per_perfume = df['notes'].str.split(', ').apply(len)

# Plotting
plt.figure(figsize=(10, 6))
plt.hist(note_counts_per_perfume, bins=range(1, note_counts_per_perfume.max() + 1), color='skyblue', edgecolor='black')
plt.title('Distribution of Number of Notes per Perfume')
plt.xlabel('Number of Notes')
plt.ylabel('Frequency')
plt.xticks(range(1, note_counts_per_perfume.max() + 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The boxplot below allows us the better visualize the outliers.

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.boxplot(note_counts_per_perfume, vert=False)
plt.title('Distribution of Number of Notes per Perfume')
plt.xlabel('Number of Notes')
plt.yticks([])
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### So, which perfume has the MOST notes in the entire dataset?
#
# * It's called '100 Tweeds' and contains 39 unique notes!

# %%
# Count the number of notes for each perfume
perfume_note_counts = df['notes'].str.split(', ').apply(len)

# Find the index of the perfume with the most notes
max_notes_index = perfume_note_counts.idxmax()

# Get the name of the perfume with the most notes
perfume_with_most_notes = df.loc[max_notes_index, 'perfume']

# Print the result
print(f"The perfume with the most notes is '{perfume_with_most_notes}' with {perfume_note_counts[max_notes_index]} notes.")
# Out:
# The perfume with the most notes is '100 Tweeds' with 39 notes.

# %% [markdown]
# ### What are the rare or unusual notes? (I am defining this as notes that only occur once)

# %%
# Flatten the list of notes
all_notes = [note.strip() for sublist in df['notes'].str.split(',') for note in sublist]

# Count the frequency of each note
note_counts = Counter(all_notes)

# Sort notes by frequency in ascending order
sorted_notes = sorted(note_counts.items(), key=lambda x: x[1])

# Print the rare or unusual notes
print("Rare or Unusual Notes:")
for note, count in sorted_notes:
    if count <= 1:  # Adjust the threshold as needed
        print(f"{note}: {count} occurrence")
# Out:
# Rare or Unusual Notes:
# south african sage: 1 occurrence
# orange honey: 1 occurrence
# turkish coffee beans: 1 occurrence
# alumroot: 1 occurrence
# black gardenia: 1 occurrence
# borneol: 1 occurrence
# eau de vie: 1 occurrence
# himalayan geranium: 1 occurrence
# moroccan mimosa: 1 occurrence
# chinese apricot: 1 occurrence
# belambra tree: 1 occurrence
# rose juliette greco: 1 occurrence
# californian fig: 1 occurrence
# wisteria petals: 1 occurrence
# kyoto rose petals: 1 occurrence
# juicy apricot: 1 occurrence
# mai tai cocktail: 1 occurrence
# red vanill-orchid: 1 occurrence
# moroccan and indian jasmine: 1 occurrence
# blueberry leaf: 1 occurrence
# japanese pink lotus: 1 occurrence
# chinese pink peony: 1 occurrence
# spanish jasmine: 1 occurrence
# white camelia: 1 occurrence
# diamond orchid: 1 occurrence
# water pepper: 1 occurrence
# beech: 1 occurrence
# hibiscus leaves: 1 occurrence
# green orchid: 1 occurrence
# japanese orchid: 1 occurrence
# katrafay: 1 occurrence
# cocobolo: 1 occurrence
# mangosteen blossom: 1 occurrence
# linaloe berry: 1 occurrence
# saw palmetto: 1 occurrence
# yohimbe: 1 occurrence
# ginkgo: 1 occurrence
# molasses: 1 occurrence
# cork: 1 occurrence
# turnera diffusa (damiana): 1 occurrence
# arbutus (madrona: 1 occurrence
# bearberry tree): 1 occurrence
# icing pink: 1 occurrence
# satin: 1 occurrence
# tennis ball: 1 occurrence
# toscanol: 1 occurrence
# tamarisk: 1 occurrence
# chayote: 1 occurrence
# georgian apricot: 1 occurrence
# crinum lily: 1 occurrence
# solomon`s seal: 1 occurrence
# blackthorn: 1 occurrence
# horchata: 1 occurrence
# yumberry: 1 occurrence
# mitti attar: 1 occurrence
# punch: 1 occurrence
# moroccan incense: 1 occurrence
# red nectarine: 1 occurrence
# blue lilies: 1 occurrence
# white honeysuckle: 1 occurrence
# hawaiian fruits: 1 occurrence
# limnophila aromatica: 1 occurrence
# surf wax: 1 occurrence
# white peach blossom: 1 occurrence
# carissa: 1 occurrence
# bbq: 1 occurrence
# pistachio leaf: 1 occurrence
# coconut rum: 1 occurrence
# gromwell: 1 occurrence
# western skunk cabbage: 1 occurrence
# sangria: 1 occurrence
# virginian patchouli: 1 occurrence
# red maple: 1 occurrence
# poinsettia: 1 occurrence
# canel\u00e9: 1 occurrence
# indian mimosa: 1 occurrence
# musk vodka: 1 occurrence
# betel pepper: 1 occurrence
# coriander extract: 1 occurrence
# sicilian peony: 1 occurrence
# chinese red currant: 1 occurrence
# frosted orange: 1 occurrence
# brown scotch tape: 1 occurrence
# bearberry: 1 occurrence
# neoprene: 1 occurrence
# ravello rose: 1 occurrence
# china rose: 1 occurrence
# geosmin: 1 occurrence
# moroccan lemon: 1 occurrence
# silk vine or milk broom: 1 occurrence
# nettle blossom: 1 occurrence
# kowhai: 1 occurrence
# kanuka: 1 occurrence
# genmaicha: 1 occurrence
# norwegian pine: 1 occurrence
# cinnamon flower: 1 occurrence
# neem tree: 1 occurrence
# himalayan poppy: 1 occurrence
# centella asiatica: 1 occurrence
# narciussus: 1 occurrence
# red currant blossom: 1 occurrence
# ground cherry: 1 occurrence
# bromelia: 1 occurrence
# acerola blossom: 1 occurrence
# carambola blossom: 1 occurrence
# umbu-caj\u00e1 | tapereb\u00e1: 1 occurrence
# synthetic civet: 1 occurrence
# sainfoins: 1 occurrence
# fig honey: 1 occurrence
# californian orange: 1 occurrence
# black locust leaf: 1 occurrence
# egyptian and indian jasmine: 1 occurrence
# coral amber: 1 occurrence
# white datura: 1 occurrence
# profiterole: 1 occurrence
# chinese patchouli: 1 occurrence
# french hyacinth: 1 occurrence
# aluminum: 1 occurrence
# sicilian bitter orange: 1 occurrence
# tibetan moss: 1 occurrence
# moepel accord: 1 occurrence
# bran: 1 occurrence
# japanese gardenia: 1 occurrence
# african freesia petals: 1 occurrence
# californian gardenia: 1 occurrence
# indonesian pepper: 1 occurrence
# holly flower: 1 occurrence
# oysters: 1 occurrence
# carnation leaves: 1 occurrence
# hoary stock: 1 occurrence
# sideritis: 1 occurrence
# mountain tea: 1 occurrence
# black locust honey: 1 occurrence
# chinotto: 1 occurrence
# kadam: 1 occurrence
# indonesian myrrh: 1 occurrence
# cloudberry: 1 occurrence
# red cyclamen: 1 occurrence
# rumex: 1 occurrence
# katsura leaf: 1 occurrence
# california cedar: 1 occurrence
# maninka: 1 occurrence
# nigerian ginger: 1 occurrence
# cassowary fruit: 1 occurrence
# canadian pine: 1 occurrence
# black pomegranate: 1 occurrence
# cosmopolitan cocktail: 1 occurrence
# madeira: 1 occurrence
# fresh almond: 1 occurrence
# satureja: 1 occurrence
# hatkora lemon: 1 occurrence
# grape leaves: 1 occurrence
# araucaria: 1 occurrence
# hungarian oakmoss: 1 occurrence
# melilotus: 1 occurrence
# madagascar sandalwood: 1 occurrence
# golden lily: 1 occurrence
# princess tree or paulownia: 1 occurrence
# hassaku: 1 occurrence
# croissant: 1 occurrence
# rainbow sorbet: 1 occurrence
# hina: 1 occurrence
# woody zion: 1 occurrence
# cupuacu: 1 occurrence
# cupuassu: 1 occurrence
# copoasu: 1 occurrence
# blue margarita: 1 occurrence
# hi-fi: 1 occurrence
# frosted apple: 1 occurrence
# brazilian spices: 1 occurrence
# white royal lily: 1 occurrence
# paramela: 1 occurrence
# pinot noir grapes: 1 occurrence
# dove tree: 1 occurrence
# co2 extracts: 1 occurrence
# jeans: 1 occurrence
# red paprika: 1 occurrence

# %% [markdown]
# ### I noticed that a lot of the unique notes above are actually regional varieties of flowers/plants -- for example: indonesian pepper, madagascar sandalwood, south african sage, chinese patchouli, etc..
#
# ### However, there are indeed some very unexpected fragrance notes in here -- such as jeans, cork, surf wax, bbq, and western skunk cabbage!
#
# ### Let's see which perfumes contained those odd notes!

# %%
# specific notes I want to investigate
specific_notes = ["jeans", "cork", "surf wax", "bbq", "western skunk cabbage"]

# Dictionary to store associated perfumes for each specific note
perfumes_with_specific_notes = {}

# Iterate through each specific note and find associated perfumes
for specific_note in specific_notes:
    associated_perfumes = df[df['notes'].str.contains(specific_note, case=False)]['perfume'].tolist()
    perfumes_with_specific_notes[specific_note] = associated_perfumes

# Print the associated perfumes for each specific note
for specific_note, perfumes in perfumes_with_specific_notes.items():
    print(f"Perfume containing '{specific_note}':")
    for perfume in perfumes:
        print(f"- {perfume}")
# Out:
# Perfume containing 'jeans':
# - Forum Jeans 2
# Perfume containing 'cork':
# - Albatross
# Perfume containing 'surf wax':
# - Pirette
# Perfume containing 'bbq':
# - Que Eau de Barbeque
# Perfume containing 'western skunk cabbage':
# - Totem Eclipse
